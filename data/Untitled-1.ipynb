# %%
import geopandas as gpd
from shapely import wkt
import numpy as np

# %%
import json

# %%
gdf = gpd.read_file('PoliceBeatsClean1.json')

# %%
gdf["coordinates"] = gdf.geometry.centroid
# Out:
# /var/folders/y4/t37jhmcx5fv_6z2p5_3s7py00000gn/T/ipykernel_4169/1269880621.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["coordinates"] = gdf.geometry.centroid

# %%
gdf["lat"] = gdf.coordinates.y
gdf["lng"] = gdf.coordinates.x

# %%
gdf = gdf[['acres', 'name', 'shape_area', 'cp_beat', 'agency', 'pol_dist',
       'response', 'id', 'pol_beat', 'fullname', 'flag', 'ruleid_1', 'message',
       'sourcethm', 'action', 'pol_sect', 'shape_len', 'lng', 'lat', 'geometry']]

# %%
gdf
# Out:
#          acres name     shape_area cp_beat agency pol_dist response    id  \
# 0      214.241  03X  10456735.4319      3X     OP        1            342
# 1      281.682  04X  12977459.8553      4X     OP        1             48
# 2      310.616  06X  13540956.6952      6X     OP        1           2546
# 3     1866.395  05Y  79093765.2073      5Y     OP        1           2628
# 4      225.218  05X  9938690.01843      5X     OP        1              8
# ..         ...  ...            ...     ...    ...      ...      ...   ...
# 109    282.393  27X  12302064.7024     27X     OP        4              3
# 110    549.377  29X  23930611.5377     29X     OP        5             19
# 111    295.576  31Z   12875312.438     31Z     OP        5             42
# 112  13616.028  31X  596679125.599     31X     OP        5             46
# 113   2689.367  35Y  119367348.016     35Y     OP        5             55
#
#     pol_beat fullname flag ruleid_1 message sourcethm action pol_sect  \
# ...

# %%
gdf.to_file("PoliceBeatsClean.json", driver="GeoJSON")
